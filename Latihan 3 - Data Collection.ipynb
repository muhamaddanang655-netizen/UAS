# %% [markdown]
# # UAS Politeknik Krakatau

# %% [markdown]
# - Nama:MUHAMAD DANANG
# - Kelas :TRPL (SEMESTER 3)
# - Dosen Pengampu : Yudistira Dwi Permana

# %% [markdown]
# ### Data Collection

# %%
# isilah kode di bawah ini
x = [1, 'semester', 3]
x[0]= 'sekarang'
print(x)


# agar menghasilkan output: ['sekarang', 'semester', 3]
# Out:
# ['sekarang', 'semester', 3]

# %% [markdown]
# penjelasan

# %%
# Hasilkan output dibawah ini menjadi saya suka python
x = ["saya", "suka", "mouse", "mousepad", "keyboard", "python", "microphone"]
print(x[0] + x[1] + x[5])
# Out:
# sayasukapython

# %% [markdown]
# penjelasan

# %%
# Menuliskan Variable Tupple

x = (5,'program',1+3j)
x[1]='Yudis'
  
# agar menghasilkan error karena tupple bersifat immutable
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 # Menuliskan Variable Tupple
#       3 x = (5,'program',1+3j)
# ----> 4 x[1]='Yudis'
#       6 # agar menghasilkan error karena tupple bersifat immutable
#       7 print(x)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# penjelasan

# %%
# Menuliskan variable Set

x = {1,2,7,2,3,13,3}

# agar menghasilkan error karena set tidak mendukung indexing
print(x[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       3 x = {1,2,7,2,3,13,3}
#       5 # agar menghasilkan error karena set tidak mendukung indexing
# ----> 6 print(x[0])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# penjelasan

# %%
# Menuliskan Variable Dictionary

x = {'nama': 'Yudis', 'umur': 21}

# agar menghasilkan output: Umur yudis menjadi 21 :v
print(x)
# Out:
# {'nama': 'Yudis', 'umur': 21}

# %% [markdown]
# penjelasan
